# %%
! pip install langchain langchain-mistralai langchain_community
# Out:
# Collecting langchain
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-mistralai
#   Downloading langchain_mistralai-0.2.12-py3-none-any.whl.metadata (2.0 kB)
# Collecting langchain_community
#   Downloading langchain_community-0.3.30-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain)
#   Downloading langchain_core-0.3.78-py3-none-any.whl.metadata (3.2 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Downloading langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Downloading langsmith-0.4.32-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from langchain) (2.11.9)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.43-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from langchain) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Downloading orjson-3.11.3-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.11.0)
# Requirement already satisfied: certifi in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.2.4-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tokenizers<1,>=0.15.1 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from langchain-mistralai) (0.22.1)
# Collecting httpx-sse<1,>=0.3.1 (from langchain-mistralai)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from tokenizers<1,>=0.15.1->langchain-mistralai) (0.35.3)
# Requirement already satisfied: filelock in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain-mistralai) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain-mistralai) (2025.9.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain-mistralai) (4.67.1)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Using cached aiohttp-3.12.15-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Downloading pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from langchain_community) (2.3.3)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached frozenlist-1.7.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached multidict-6.6.4-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached propcache-0.3.2-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached yarl-1.20.1-cp313-cp313-win_amd64.whl.metadata (76 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: colorama in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain-mistralai) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\thoma\documents\repositories\mistral-labs\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 13.0 MB/s  0:00:00
# Downloading langchain_core-0.3.78-py3-none-any.whl (449 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Downloading langsmith-0.4.32-py3-none-any.whl (386 kB)
# Downloading sqlalchemy-2.0.43-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 19.2 MB/s  0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading langchain_mistralai-0.2.12-py3-none-any.whl (16 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading langchain_community-0.3.30-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 15.1 MB/s  0:00:00
# Using cached aiohttp-3.12.15-cp313-cp313-win_amd64.whl (449 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached multidict-6.6.4-cp313-cp313-win_amd64.whl (45 kB)
# Downloading pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.20.1-cp313-cp313-win_amd64.whl (86 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached frozenlist-1.7.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading greenlet-3.2.4-cp313-cp313-win_amd64.whl (299 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading orjson-3.11.3-cp313-cp313-win_amd64.whl (131 kB)
# Using cached propcache-0.3.2-cp313-cp313-win_amd64.whl (40 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, tenacity, propcache, orjson, mypy-extensions, multidict, marshmallow, jsonpointer, httpx-sse, greenlet, frozenlist, attrs, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, requests-toolbelt, jsonpatch, aiosignal, pydantic-settings, langsmith, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain-mistralai, langchain, langchain_community
#
#    - --------------------------------------  1/28 [tenacity]
#    ---- -----------------------------------  3/28 [orjson]
#    -------- -------------------------------  6/28 [marshmallow]
#    ---------- -----------------------------  7/28 [jsonpointer]
#    ------------ ---------------------------  9/28 [greenlet]
#    ------------ ---------------------------  9/28 [greenlet]
#    --------------- ------------------------ 11/28 [attrs]
#    ------------------ --------------------- 13/28 [yarl]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    --------------------- ------------------ 15/28 [SQLAlchemy]
#    ---------------------- ----------------- 16/28 [requests-toolbelt]
#    ------------------------ --------------- 17/28 [jsonpatch]
#    --------------------------- ------------ 19/28 [pydantic-settings]
#    ---------------------------- ----------- 20/28 [langsmith]
#    ---------------------------- ----------- 20/28 [langsmith]
#    ---------------------------- ----------- 20/28 [langsmith]
#    ------------------------------ --------- 21/28 [dataclasses-json]
#    ------------------------------- -------- 22/28 [aiohttp]
#    ------------------------------- -------- 22/28 [aiohttp]
#    ------------------------------- -------- 22/28 [aiohttp]
#    ------------------------------- -------- 22/28 [aiohttp]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    ---------------------------------- ----- 24/28 [langchain-text-splitters]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    ------------------------------------- -- 26/28 [langchain]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    -------------------------------------- - 27/28 [langchain_community]
#    ---------------------------------------- 28/28 [langchain_community]
#
# Successfully installed SQLAlchemy-2.0.43 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 attrs-25.3.0 dataclasses-json-0.6.7 frozenlist-1.7.0 greenlet-3.2.4 httpx-sse-0.4.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.27 langchain-core-0.3.78 langchain-mistralai-0.2.12 langchain-text-splitters-0.3.11 langchain_community-0.3.30 langsmith-0.4.32 marshmallow-3.26.1 multidict-6.6.4 mypy-extensions-1.1.0 orjson-3.11.3 propcache-0.3.2 pydantic-settings-2.11.0 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-inspect-0.9.0 yarl-1.20.1 zstandard-0.25.0

# %%
import os
from langchain_community.document_loaders import TextLoader
from langchain_mistralai.chat_models import ChatMistralAI
from langchain_mistralai.embeddings import MistralAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_retrieval_chain


MISTRAL_API_KEY=os.getenv("MISTRAL_API_KEY")

# Load data
loader = TextLoader("sample_data/paul_graham_essay.txt")
docs = loader.load()

# Split text into chunks
text_splitter = RecursiveCharacterTextSplitter()

documents = text_splitter.split_documents(docs)

# Define the embedding model
embeddings = MistralAIEmbeddings(model="mistral-embed", mistral_api_key=MISTRAL_API_KEY)

# Create the vector store
vector = FAISS.from_documents(documents, embeddings)

# Define a retriever interface
retriever = vector.as_retriever()

# Define LLM
model = ChatMistralAI(mistral_api_key=MISTRAL_API_KEY,model="mistral-tiny")

# Define prompt template
prompt = ChatPromptTemplate.from_template("""
    Answer the following question based only on the provided context:
    {context}
    Question: {input}"""
)


# Create a retrieval chain to answer questions
document_chain = create_stuff_documents_chain(model, prompt)
retrieval_chain = create_retrieval_chain(retriever, document_chain)
response = retrieval_chain.invoke({"input": "What were the two main things the author worked on before college?"})
# Out:
# c:\Users\thoma\Documents\repositories\Mistral-labs\.venv\Lib\site-packages\pydantic\main.py:253: UserWarning: Could not download mistral tokenizer from Huggingface for calculating batch sizes. Set a Huggingface token via the HF_TOKEN environment variable to download the real tokenizer. Falling back to a dummy tokenizer that uses `len()`.
#   validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)

# %%
print(response["answer"])
# Out:
# Before college, the two main things the author worked on outside of school were writing short stories and programming.
